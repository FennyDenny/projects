# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sn

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("Abalone.csv")
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %% [markdown]
# There are 4177 rows and 9 columns

# %%
df.shape
# Out:
# (4177, 9)

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %% [markdown]
# These gives the statistical data of dataset

# %%
df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %% [markdown]
# It gives the data types of the columns here sex is object, rings is integers other columns are float

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# There is no null values

# %%
df["Rings"].unique()
# Out:
# array([15,  7,  9, 10,  8, 20, 16, 19, 14, 11, 12, 18, 13,  5,  4,  6, 21,
#        17, 22,  1,  3, 26, 23, 29,  2, 27, 25, 24], dtype=int64)

# %%
print(df['Rings'].value_counts())
# Out:
# 9     689
# 10    634
# 8     568
# 11    487
# 7     391
# 12    267
# 6     259
# 13    203
# 14    126
# 5     115
# 15    103
# 16     67
# 17     58
# 4      57
# 18     42
# 19     32
# 20     26
# 3      15
# 21     14
# 23      9
# 22      6
# 27      2
# 24      2
# 26      1
# 29      1
# 25      1
# 1       1
# 2       1
# Name: Rings, dtype: int64

# %% [markdown]
# There are equality in no. of rings

# %% [markdown]
# # EDA

# %% [markdown]
# UNIVARIATE ANALYSIS

# %%
sn.countplot(df['Rings'])
# Out:
# <AxesSubplot:xlabel='Rings', ylabel='count'>

# %% [markdown]
# not equally distributed

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df1=df.apply(LabelEncoder().fit_transform)

# %% [markdown]
# changed the strings to integers

# %%
df1
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2      66        56      18           715             417
# 1       2      45        36      17           285             178
# 2       0      81        67      26           962             480
# 3       2      63        56      24           718             400
# 4       1      41        34      15           253             159
# ...   ...     ...       ...     ...           ...             ...
# 4172    0      88        73      32          1289             698
# 4173    2      93        71      26          1411             832
# 4174    2      95        78      40          1727             994
# 4175    0     100        80      29          1610            1005
# 4176    2     117        94      38          2348            1461
#
#       Viscera weight  Shell weight  Rings
# 0                199           263     14
# 1                 94           113      6
# 2                280           374      8
# ...

# %%
dfx=df1.iloc[:,0:8]
dfx
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2      66        56      18           715             417
# 1       2      45        36      17           285             178
# 2       0      81        67      26           962             480
# 3       2      63        56      24           718             400
# 4       1      41        34      15           253             159
# ...   ...     ...       ...     ...           ...             ...
# 4172    0      88        73      32          1289             698
# 4173    2      93        71      26          1411             832
# 4174    2      95        78      40          1727             994
# 4175    0     100        80      29          1610            1005
# 4176    2     117        94      38          2348            1461
#
#       Viscera weight  Shell weight
# 0                199           263
# 1                 94           113
# 2                280           374
# ...

# %%
dfy=df.iloc[:,-1]
dfy
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4177, dtype: int64

# %%
dfy.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4177, dtype: int64>

# %%
dfy.head()
# Out:
# 0    15
# 1     7
# 2     9
# 3    10
# 4     7
# Name: Rings, dtype: int64

# %%
df1.describe()
# Out:
#                Sex       Length     Diameter       Height  Whole weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean      1.052909    79.801053    64.576969    26.848456   1155.477137
# std       0.822240    23.998661    19.841382     7.708237    660.106216
# min       0.000000     0.000000     0.000000     0.000000      0.000000
# 25%       0.000000    65.000000    53.000000    22.000000    600.000000
# 50%       1.000000    84.000000    68.000000    27.000000   1142.000000
# 75%       2.000000    98.000000    79.000000    32.000000   1695.000000
# max       2.000000   133.000000   110.000000    50.000000   2428.000000
#
#        Shucked weight  Viscera weight  Shell weight        Rings
# count     4177.000000     4177.000000   4177.000000  4177.000000
# mean       658.703615      354.047881    413.307637     8.933445
# std        384.626787      209.390934    229.342991     3.222790
# ...

# %% [markdown]
# It shows the statstical values of the data

# %%
sn.displot(df1["Sex"])

# %%
sn.displot(df1["Length"])

# %%
sn.displot(df1["Diameter"])

# %%
sn.displot(df1["Height"])

# %%
sn.displot(df1["Whole weight"])

# %%
sn.displot(df1["Shucked weight"])

# %%
sn.displot(df1["Viscera weight"])

# %%
sn.displot(df1["Shell weight"])

# %% [markdown]
# Got the displot of the columns

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize=[10,6])
plt.title("comparison between Sex and Rings")
sn.scatterplot(df['Sex'],df['Rings'],hue=df["Rings"])
# Out:
# <AxesSubplot:title={'center':'comparison between Sex and Rings'}, xlabel='Sex', ylabel='Rings'>

# %%
plt.figure(figsize=[10,6])
plt.title("comparison between Length and Rings")
sn.scatterplot(df['Length'],df['Rings'],hue=df["Rings"])
# Out:
# <AxesSubplot:title={'center':'comparison between Length and Rings'}, xlabel='Length', ylabel='Rings'>

# %%
plt.figure(figsize=[10,6])
plt.title("comparison between Diameter and Rings")
sn.scatterplot(df['Diameter'],df['Rings'],hue=df["Rings"])
# Out:
# <AxesSubplot:title={'center':'comparison between Diameter and Rings'}, xlabel='Diameter', ylabel='Rings'>

# %%
plt.figure(figsize=[10,6])
plt.title("comparison between Height and Rings")
sn.scatterplot(df['Height'],df['Rings'],hue=df["Rings"])
# Out:
# <AxesSubplot:title={'center':'comparison between Height and Rings'}, xlabel='Height', ylabel='Rings'>

# %%
plt.figure(figsize=[10,6])
plt.title("comparison between Whole weight and Rings")
sn.scatterplot(df['Whole weight'],df['Rings'],hue=df["Rings"])
# Out:
# <AxesSubplot:title={'center':'comparison between Whole weight and Rings'}, xlabel='Whole weight', ylabel='Rings'>

# %%
plt.figure(figsize=[10,6])
plt.title("comparison between Shucked weight and Rings")
sn.scatterplot(df['Shucked weight'],df['Rings'],hue=df["Rings"])
# Out:
# <AxesSubplot:title={'center':'comparison between Shucked weight and Rings'}, xlabel='Shucked weight', ylabel='Rings'>

# %%
plt.figure(figsize=[10,6])
plt.title("comparison between Viscera weight and Rings")
sn.scatterplot(df['Viscera weight'],df['Rings'],hue=df["Rings"])
# Out:
# <AxesSubplot:title={'center':'comparison between Viscera weight and Rings'}, xlabel='Viscera weight', ylabel='Rings'>

# %%
plt.figure(figsize=[10,6])
plt.title("comparison between Shell weight and Rings")
sn.scatterplot(df['Shell weight'],df['Rings'],hue=df["Rings"])
# Out:
# <AxesSubplot:title={'center':'comparison between Shell weight and Rings'}, xlabel='Shell weight', ylabel='Rings'>

# %% [markdown]
# Got the scatter plot of the columns with rings

# %%
sn.pairplot(df,hue='Rings')

# %%
cor=df.corr()
cor
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole weight          0.966375      0.955355  0.540390
# ...

# %%
plt.figure(figsize=[30,20])
sn.heatmap(cor,annot=True,linewidths=6,linecolor='r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# No columns Negatively correlated with Rings

# %%
df1.plot(kind="box",subplots=True,layout=(2,5))
# Out:
# Sex                  AxesSubplot(0.125,0.536818;0.133621x0.343182)
# Length            AxesSubplot(0.285345,0.536818;0.133621x0.343182)
# Diameter           AxesSubplot(0.44569,0.536818;0.133621x0.343182)
# Height            AxesSubplot(0.606034,0.536818;0.133621x0.343182)
# Whole weight      AxesSubplot(0.766379,0.536818;0.133621x0.343182)
# Shucked weight          AxesSubplot(0.125,0.125;0.133621x0.343182)
# Viscera weight       AxesSubplot(0.285345,0.125;0.133621x0.343182)
# Shell weight          AxesSubplot(0.44569,0.125;0.133621x0.343182)
# Rings                AxesSubplot(0.606034,0.125;0.133621x0.343182)
# dtype: object

# %%
from scipy.stats import zscore#To remove outliers
z=np.abs(zscore(df['Length']))
z
# Out:
# array([0.57455813, 1.44898585, 0.05003309, ..., 0.6329849 , 0.84118198,
#        1.54905203])

# %%
from scipy.stats import zscore#To remove outliers
z=np.abs(zscore(df['Diameter']))
z
# Out:
# array([0.43214879, 1.439929  , 0.12213032, ..., 0.67640943, 0.77718745,
#        1.48263359])

# %%
from scipy.stats import zscore#To remove outliers
z=np.abs(zscore(df['Height']))
z
# Out:
# array([1.06442415, 1.18397831, 0.10799087, ..., 1.56576738, 0.25067161,
#        1.32665906])

# %% [markdown]
# Removed the outliers by using zscore

# %% [markdown]
# # SKEWNESS

# %%
df1.skew()
# Out:
# Sex              -0.098155
# Length           -0.636399
# Diameter         -0.607999
# Height           -0.255142
# Whole weight      0.077305
# Shucked weight    0.236225
# Viscera weight    0.364429
# Shell weight      0.135640
# Rings             1.108353
# dtype: float64

# %% [markdown]
# No skewness present

# %%
x=df1.iloc[:,0:8]
print(x.head())
print(x.shape)
x.columns
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    2      66        56      18           715             417
# 1    2      45        36      17           285             178
# 2    0      81        67      26           962             480
# 3    2      63        56      24           718             400
# 4    1      41        34      15           253             159
#
#    Viscera weight  Shell weight
# 0             199           263
# 1              94           113
# 2             280           374
# 3             225           273
# 4              76            87
# (4177, 8)
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight'],
#       dtype='object')

# %%
y=df1.iloc[:,-1]
print(y.head())
print(y.shape)
# Out:
# 0    14
# 1     6
# 2     8
# 3     9
# 4     6
# Name: Rings, dtype: int64
# (4177,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
preddtc=dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 0.20739666424945613
#               precision    recall  f1-score   support
#
#            2       0.50      0.67      0.57         3
#            3       0.36      0.24      0.29        21
#            4       0.38      0.36      0.37        50
#            5       0.25      0.24      0.24        84
#            6       0.34      0.29      0.32       144
#            7       0.23      0.25      0.24       179
#            8       0.25      0.24      0.24       229
#            9       0.22      0.21      0.22       213
#           10       0.18      0.21      0.19       155
#           11       0.10      0.09      0.10        88
#           12       0.07      0.08      0.07        61
#           13       0.08      0.08      0.08        37
#           14       0.07      0.06      0.07        34
#           15       0.08      0.10      0.09        21
#           16       0.04      0.06      0.05        17
#           17       0.00      0.00      0.00        15
# ...

# %%
from sklearn.svm import SVC
svc=SVC(kernel='rbf')#It is a type of kernel we have aligned. Rbf is radial basis function.
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.2704858593183466
#               precision    recall  f1-score   support
#
#            2       0.00      0.00      0.00         3
#            3       0.00      0.00      0.00        21
#            4       0.00      0.00      0.00        50
#            5       0.24      0.52      0.33        84
#            6       0.31      0.19      0.23       144
#            7       0.28      0.46      0.35       179
#            8       0.27      0.38      0.32       229
#            9       0.24      0.40      0.30       213
#           10       0.32      0.30      0.31       155
#           11       0.00      0.00      0.00        88
#           12       0.00      0.00      0.00        61
#           13       0.00      0.00      0.00        37
#           14       0.00      0.00      0.00        34
#           15       0.00      0.00      0.00        21
#           16       0.00      0.00      0.00        17
#           17       0.00      0.00      0.00        15
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
predknn=knn.predict(x_test)
print(accuracy_score(y_test,predknn))
print(classification_report(y_test,predsvc))
# Out:
# 0.23712835387962292
#               precision    recall  f1-score   support
#
#            2       0.00      0.00      0.00         3
#            3       0.00      0.00      0.00        21
#            4       0.00      0.00      0.00        50
#            5       0.24      0.52      0.33        84
#            6       0.31      0.19      0.23       144
#            7       0.28      0.46      0.35       179
#            8       0.27      0.38      0.32       229
#            9       0.24      0.40      0.30       213
#           10       0.32      0.30      0.31       155
#           11       0.00      0.00      0.00        88
#           12       0.00      0.00      0.00        61
#           13       0.00      0.00      0.00        37
#           14       0.00      0.00      0.00        34
#           15       0.00      0.00      0.00        21
#           16       0.00      0.00      0.00        17
#           17       0.00      0.00      0.00        15
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

# %%
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
rfc.score(x_train,y_train)
predrfc=rfc.predict(x_test)
print(accuracy_score(y_test,predrfc))
print(classification_report(y_test,predrfc))
# Out:
# 0.2639593908629442
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            2       0.00      0.00      0.00         3
#            3       0.40      0.29      0.33        21
#            4       0.50      0.42      0.46        50
#            5       0.30      0.31      0.31        84
#            6       0.37      0.32      0.34       144
#            7       0.30      0.38      0.34       179
#            8       0.26      0.34      0.30       229
#            9       0.25      0.28      0.26       213
#           10       0.23      0.25      0.24       155
#           11       0.18      0.11      0.14        88
#           12       0.10      0.11      0.11        61
#           13       0.14      0.08      0.10        37
#           14       0.08      0.03      0.04        34
#           15       0.09      0.05      0.06        21
#           16       0.00      0.00      0.00        17
# ...

# %% [markdown]
# By using RandomForest Classifier .Got accuracy as 1
#
# Got the accuracy in DecisionTreeClassifier as 0.21 . Got accuracy of SVC and KNN classifiers as 0.27 & 0.24 respectivley. To check the best accuracy for which model, going to find cross validation score

# %% [markdown]
# # Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score 
print(cross_val_score(dtc,x,y,cv=5).mean())
# Out:
# 0.20349998567458383

# %%
print(cross_val_score(svc,x,y,cv=5).mean())
# Out:
# 0.2621539695728161

# %%
print(cross_val_score(knn,x,y,cv=5).mean())
# Out:
# 0.22337048391255765

# %%
print(cross_val_score(rfc,x,y,cv=5).mean())
# Out:
# 0.2523381944245481

# %% [markdown]
# Difference between dtc is 0.01,Difference between  svc is0.01 , Difference between knn is 0.01 and rfc is 0.01

# %% [markdown]
# So DecisionTreeClassifier is having best accuracy and its giving the best model also.

# %% [markdown]
# # Hyper parameter tunning

# %%
from sklearn.model_selection import GridSearchCV
import numpy as np

# %%
parameter={'max_depth':np.arange(2,10),
          'criterion':['gini','entropy'],
          'splitter':['best','random'],
          'max_features':['auto','sqrt','log2']}

# %% [markdown]
# Created the parameter list

# %%
GCV=GridSearchCV(DecisionTreeClassifier(),parameter,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': array([2, 3, 4, 5, 6, 7, 8, 9]),
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']})

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 5,
#  'max_features': 'auto',
#  'splitter': 'best'}

# %% [markdown]
# These are the best parameter forms.

# %%
final_model=DecisionTreeClassifier(criterion='gini',max_depth= 5, max_features='auto',splitter= 'best')
final_model.fit(x_train,y_train)
pred=final_model.predict(x_test)
accuracy=accuracy_score(y_test,pred)
print (accuracy*100)
# Out:
# 27.628716461203773

# %% [markdown]
# So here got the best model with DecisionTreeClassifier with accuracy 27%. We used the parmeters criterion='gini',max_depth= 5, max_features='auto',splitter= 'best'

# %% [markdown]
# For predicting the value using liear regression

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Fitting the data into x-train and y-train

# %%
lm.coef_
# Out:
# array([ 0.06593725, -0.00754312,  0.04170927,  0.1257889 ,  0.00790772,
#        -0.01367156, -0.00546346,  0.00594893])

# %% [markdown]
# Got the coefficient of the Linear Regression

# %%
lm.intercept_
# Out:
# 2.774378330283696

# %% [markdown]
# Got the intercept of the linear regression

# %%
pred=lm.predict(x_test)# predicting the value
print("predicted value is",pred)
print("actual value is",y_test)
# Out:
# predicted value is [11.31729243  9.07821952 14.54183434 ...  6.68978601  6.60274022
#   6.49801606]
# actual value is 866      8
# 1483     7
# 599     15
# 1702     8
# 670     13
#         ..
# 601      9
# 233      6
# 2644     7
# 931      5
# 3431     4
# Name: Rings, Length: 1379, dtype: int64

# %% [markdown]
# Got the predicted value and the actual values

# %%
print("mean absoute value",mean_absolute_error(y_test,pred))
print("mean squared error",mean_squared_error(y_test,pred))
print ("Root mean squared error",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# mean absoute value 1.6105161512861803
# mean squared error 4.874418936971109
# Root mean squared error 2.207808627796148

# %% [markdown]
# Got mean absolute value as 1.61, mean squared error as 4.9 and root mean squared error as 2.2

# %%
t=np.array([0.123,0.53723,0.496,1.09,0.54143,0.26557,0.1719,0.166])

# %%
t.shape
# Out:
# (8,)

# %%
t=t.reshape(1,-1)
t.shape
# Out:
# (1, 8)

# %%
lm.predict(t)
# Out:
# array([2.93693299])

# %% [markdown]
# the predicted value is 2.934

# %% [markdown]
# # Saving the model

# %%
import joblib
joblib.dump(final_model,"Final Model of Abalone.pkl")
# Out:
# ['Final Model of Abalone.pkl']

# %% [markdown]
# saved the model
